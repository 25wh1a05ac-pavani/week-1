# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05ac-pavani/week-1/blob/main/WEEK%204/U8_Data_Cleaning_Part2_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None)
print('Setup complete. pandas', pd.__version__)
# Out:
# Setup complete. pandas 2.2.3

# %%
df = pd.DataFrame({
    'city':   ['pune', 'delhi', 'mumbai', 'pune', 'delhi', 'mumbai', 'pune', 'delhi'],
    'size':   ['small', 'large', 'medium', 'medium', 'small', 'large', 'large', 'small'],
    'age':    [25, 41, 33, 29, 52, 38, 46, 22],
    'income': [38000, 92000, 55000, 47000, 120000, 76000, 88000, 41000],
    'bought': [0, 1, 0, 0, 1, 1, 1, 0],   # target
})
df
# Out:
#      city    size  age  income  bought
# 0    pune   small   25   38000       0
# 1   delhi   large   41   92000       1
# 2  mumbai  medium   33   55000       0
# 3    pune  medium   29   47000       0
# 4   delhi   small   52  120000       1
# 5  mumbai   large   38   76000       1
# 6    pune   large   46   88000       1
# 7   delhi   small   22   41000       0

# %%
city_ohe = pd.get_dummies(df['city'], prefix='city').astype(int)
city_ohe
# Out:
#    city_delhi  city_mumbai  city_pune
# 0           0            0          1
# 1           1            0          0
# 2           0            1          0
# 3           0            0          1
# 4           1            0          0
# 5           0            1          0
# 6           0            0          1
# 7           1            0          0

# %%
size_order = {'small': 0, 'medium': 1, 'large': 2}
df['size_code'] = df['size'].map(size_order)
df[['size', 'size_code']]
# Out:
#      size  size_code
# 0   small          0
# 1   large          2
# 2  medium          1
# 3  medium          1
# 4   small          0
# 5   large          2
# 6   large          2
# 7   small          0

# %%
import pandas as pd

# Create the DataFrame
df = pd.DataFrame({
    'city': ['London', 'New York', 'London', 'Paris'],
    'size': ['Small', 'Large', 'Medium', 'Small']
})

# Size order
size_order = {
    'Small': 1,
    'Medium': 2,
    'Large': 3
}
# 1. one-hot encode just the 'city' column of the whole df
# YOUR CODE HERE
df_encoded = pd.get_dummies(df, columns=['city'])
# 2. ordinal-encode 'size' (map with size_order)
# YOUR CODE HERE
df_encoded['size'] = df_encoded['size'].map(size_order)
# 3. Why one-hot is wrong for size / ordinal is wrong for city: ...   (comment)
print(df_encoded)
# One-hot is wrong for size because size has a natural order.
# Ordinal encoding is wrong for city because cities have no natural order.
# Out:
#    size  city_London  city_New York  city_Paris
# 0     1         True          False       False
# 1     3        False           True       False
# 2     2         True          False       False
# 3     1        False          False        True

# %%
print(df[['age', 'income']].describe().loc[['min', 'max', 'mean']])
# Out:
#         age    income
# min   22.00   38000.0
# max   52.00  120000.0
# mean  35.75   69625.0

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Create sample DataFrame
df = pd.DataFrame({
    'age': [20, 25, 30, 35, 40],
    'income': [20000, 30000, 40000, 50000, 60000]
})

# Select numerical columns
num = df[['age', 'income']]

# Standardisation: mean = 0, std = 1
z = StandardScaler().fit_transform(num)

# Min-Max scaling: range = 0 to 1
m = MinMaxScaler().fit_transform(num)

# Print Standardised values
print('Standardised (mean~0, std~1):')
print(pd.DataFrame(z, columns=['age', 'income']).round(2).head(3))

# Print Min-Max values
print('\nMin-Max (range 0..1):')
print(pd.DataFrame(m, columns=['age', 'income']).round(2).head(3))
# Out:
# Standardised (mean~0, std~1):
#     age  income
# 0 -1.41   -1.41
# 1 -0.71   -0.71
# 2  0.00    0.00
#
# Min-Max (range 0..1):
#     age  income
# 0  0.00    0.00
# 1  0.25    0.25
# 2  0.50    0.50

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

income = df[['income']]   # 2D shape for sklearn

# 1. Standardise -> check mean ~0, std ~1
standardised = StandardScaler().fit_transform(income)

print("Standardised:")
print(standardised)

print("Mean:", standardised.mean())
print("Std:", standardised.std())

# 2. Min-Max scale -> check min 0, max 1
minmax = MinMaxScaler().fit_transform(income)

print("\nMin-Max scaled:")
print(minmax)

print("Min:", minmax.min())
print("Max:", minmax.max())

# 3. Needs scaling: income, age, salary, other numerical features
#    Doesn't need it: already scaled/encoded categorical features
# Out:
# Standardised:
# [[-1.41421356]
#  [-0.70710678]
#  [ 0.        ]
#  [ 0.70710678]
#  [ 1.41421356]]
# Mean: -4.4408920985006264e-17
# Std: 1.0
#
# Min-Max scaled:
# [[0.  ]
#  [0.25]
#  [0.5 ]
#  [0.75]
#  [1.  ]]
# Min: 0.0
# Max: 1.0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Sample dataset
df = pd.DataFrame({
    'age': [20, 25, 30, 35, 40, 45, 50, 55],
    'income': [20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000],
    'bought': [0, 0, 1, 1, 1, 0, 1, 1]
})

# Select features and target
X = df[['age', 'income']]
y = df['bought']

# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

# Standardisation
scaler = StandardScaler()

# FIT + transform only on training data
X_train_s = scaler.fit_transform(X_train)

# Only transform test data
X_test_s = scaler.transform(X_test)

# Display results
print('train rows:', X_train.shape[0], '| test rows:', X_test.shape[0])

print('scaler learned mean from TRAIN only:',
      scaler.mean_.round(1))
# Out:
# train rows: 6 | test rows: 2
# scaler learned mean from TRAIN only: [3.67000e+01 5.33333e+04]

# %%
wrong_mean = StandardScaler().fit(X).mean_

# 1b. RIGHT: fit on TRAIN only
right_mean = StandardScaler().fit(X_train).mean_

print('fit-on-all mean :', wrong_mean.round(1))
print('fit-on-train mean:', right_mean.round(1))

# 2. Why fitting on all data is a problem: ...   (write your answer)
# Out:
# fit-on-all mean : [3.75e+01 5.50e+04]
# fit-on-train mean: [3.67000e+01 5.33333e+04]

# %%
fe = df.copy()
# combine: income per year of age (a crude 'earning rate')
fe['income_per_age'] = (fe['income'] / fe['age']).round(0)
# bin: turn continuous age into life-stage buckets
fe['age_group'] = pd.cut(fe['age'], bins=[0, 30, 45, 100],
                         labels=['young', 'mid', 'senior'])
fe[['age', 'income', 'income_per_age', 'age_group']]
# Out:
#    age  income  income_per_age age_group
# 0   20   20000          1000.0     young
# 1   25   30000          1200.0     young
# 2   30   40000          1333.0     young
# 3   35   50000          1429.0       mid
# 4   40   60000          1500.0       mid
# 5   45   70000          1556.0       mid
# 6   50   80000          1600.0    senior
# 7   55   90000          1636.0    senior

# %%
dates = pd.to_datetime(['2024-01-06', '2024-03-15', '2024-07-21', '2024-12-25'])
d = pd.DataFrame({'date': dates})
d['day_of_week'] = d['date'].dt.day_name()   # Monday, Tuesday, ...
d['month']       = d['date'].dt.month
d['is_weekend']  = d['date'].dt.dayofweek >= 5
d
# Out:
#         date day_of_week  month  is_weekend
# 0 2024-01-06    Saturday      1        True
# 1 2024-03-15      Friday      3       False
# 2 2024-07-21      Sunday      7        True
# 3 2024-12-25   Wednesday     12       False

# %%
import pandas as pd

ex = df.copy()

# 1. High-earner flag (income > median)
median_income = ex['income'].median()
ex['high_earner'] = ex['income'] > median_income

# 2. Bin income into 3 buckets using pd.cut
ex['income_bucket'] = pd.cut(
    ex['income'],
    bins=3,
    labels=['Low', 'Medium', 'High']
)

# 3. Show income + the new columns
print(ex[['income', 'high_earner', 'income_bucket']])
# Out:
#    income  high_earner income_bucket
# 0   20000        False           Low
# 1   30000        False           Low
# 2   40000        False           Low
# 3   50000        False        Medium
# 4   60000         True        Medium
# 5   70000         True          High
# 6   80000         True          High
# 7   90000         True          High

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression

num_cols = ['age', 'income']
cat_cols = ['city', 'size']

# scale the numbers, one-hot the categories — all in one object
pre = ColumnTransformer([
    ('num', StandardScaler(), num_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols),
])
pipe = Pipeline([('prep', pre), ('model', LogisticRegression(max_iter=1000))])
print(pipe)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['age', 'income']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['city', 'size'])])),
#                 ('model', LogisticRegression(max_iter=1000))])

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# Sample dataset
df = pd.DataFrame({
    'age': [20, 25, 30, 35, 40, 45, 50, 55],
    'income': [20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000],
    'city': ['London', 'Paris', 'London', 'Paris',
             'London', 'Paris', 'London', 'Paris'],
    'bought': [0, 0, 1, 1, 1, 0, 1, 1]
})

# Numerical and categorical columns
num_cols = ['age', 'income']
cat_cols = ['city']

# Features and target
X = df[num_cols + cat_cols]
y = df['bought']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

# Preprocessing
preprocessor = ColumnTransformer([
    ('num', StandardScaler(), num_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols)
])

# Pipeline
pipe = Pipeline([
    ('preprocessing', preprocessor),
    ('model', LogisticRegression())
])

# Fit on training data only
pipe.fit(X_train, y_train)

# Evaluate on test data
acc = pipe.score(X_test, y_test)

print('Test accuracy:', round(acc, 2))
print('(small toy dataset — the point is the leak-free workflow, not the score)')
# Out:
# Test accuracy: 0.5
# (small toy dataset — the point is the leak-free workflow, not the score)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

Xn = df[['age', 'income']]
yn = df['bought']

# 1. Pipeline: MinMaxScaler -> LogisticRegression
pipe = Pipeline([
    ('scaler', MinMaxScaler()),
    ('model', LogisticRegression())
])

# 2. Split + fit on train
X_train, X_test, y_train, y_test = train_test_split(
    Xn, yn, test_size=0.25, random_state=0
)

pipe.fit(X_train, y_train)

# 3. Print test accuracy
accuracy = pipe.score(X_test, y_test)

print("Test accuracy:", round(accuracy, 2))
# Out:
# Test accuracy: 0.5
