# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05ac-pavani/week-1/blob/main/Pandas_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

print("--- Intermediate Pandas Exercise ---")
print("Complete each task by writing the requested Pandas code.")
print("------------------------------------")

# Task 1: Basic Pandas Functions and Converting Arrays to DataFrames
print("\n--- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---")
# 1.1 Create a Pandas Series named 's1_1' from a list of numbers [10, 20, 30, 40, 50].
# 1.2 Create a 3x4 NumPy array named 'np_array1_2' with random integers between 1 and 100.
# 1.3 Convert 'np_array1_2' into a Pandas DataFrame named 'df1_3' with columns 'A', 'B', 'C', 'D'.

# Your code for Task 1 here:
import pandas as pd
import numpy as np


# 1.1 Create a Pandas Series
s1_1 = pd.Series([10, 20, 30, 40, 50])

# 1.2 Create a 3x4 NumPy array with random integers from 1 to 100
np_array1_2 = np.random.randint(1, 101, size=(3, 4))

# 1.3 Convert NumPy array into DataFrame
df1_3 = pd.DataFrame(np_array1_2, columns=['A', 'B', 'C', 'D'])

print("Series:")
print(s1_1)

print("\nNumPy Array:")
print(np_array1_2)

print("\nDataFrame:")
print(df1_3)


# Task 2: Synthetic Data Generation for Practice
print("\n--- Task 2: Synthetic Data Generation for Practice ---")
# Create a DataFrame named 'df_sales' with 100 rows and the following columns:
# - 'Date': A range of dates from '2023-01-01' to '2023-04-09' (inclusive).
# - 'Region': Randomly chosen from ['East', 'West', 'North', 'South'].
# - 'Product': Randomly chosen from ['Laptop', 'Mouse', 'Keyboard', 'Monitor'].
# - 'Sales': Random integers between 100 and 1000.
# - 'Quantity': Random integers between 1 and 10.
# - Introduce 5 random NaN values in the 'Sales' column and 3 random NaN values in the 'Quantity' column.

# Your code for Task 2 here:

# Create 100 dates
dates = pd.date_range(start='2023-01-01', end='2023-04-09', periods=100)

# Create DataFrame
df_sales = pd.DataFrame({
    'Date': dates,
    'Region': np.random.choice(['East', 'West', 'North', 'South'], 100),
    'Product': np.random.choice(['Laptop', 'Mouse', 'Keyboard', 'Monitor'], 100),
    'Sales': np.random.randint(100, 1001, 100),
    'Quantity': np.random.randint(1, 11, 100)
})

# Introduce 5 NaN values in Sales
sales_nan_indices = np.random.choice(df_sales.index, 5, replace=False)
df_sales.loc[sales_nan_indices, 'Sales'] = np.nan

# Introduce 3 NaN values in Quantity
quantity_nan_indices = np.random.choice(df_sales.index, 3, replace=False)
df_sales.loc[quantity_nan_indices, 'Quantity'] = np.nan

print(df_sales)

# Introduce NaN values



# Task 3: Indexing and Slicing in DataFrames
print("\n--- Task 3: Indexing and Slicing in DataFrames ---")
# Use 'df_sales' from Task 2.
# 3.1 Select only the 'Region' and 'Sales' columns. Store it in 'df3_1'.
# 3.2 Select rows where 'Product' is 'Laptop'. Store it in 'df3_2'.
# 3.3 Select rows where 'Region' is 'East' AND 'Sales' are greater than 500. Store it in 'df3_3'.
# 3.4 Select the 'Sales' value for the first entry where 'Product' is 'Monitor' (use .loc and .iloc). Store it in 'val3_4'.

# Your code for Task 3 here:


# 3.1 Select Region and Sales columns
df3_1 = df_sales[['Region', 'Sales']]

# 3.2 Select rows where Product is Laptop
df3_2 = df_sales[df_sales['Product'] == 'Laptop']

# 3.3 Select rows where Region is East AND Sales > 500
df3_3 = df_sales[
    (df_sales['Region'] == 'East') &
    (df_sales['Sales'] > 500)
]

# 3.4 Select Sales value for first Monitor entry
monitor_rows = df_sales[df_sales['Product'] == 'Monitor']

val3_4 = df_sales.loc[monitor_rows.index[0], 'Sales']

print("Region and Sales:")
print(df3_1)

print("\nLaptop rows:")
print(df3_2)

print("\nEast region with Sales > 500:")
print(df3_3)

print("\nFirst Monitor Sales:", val3_4)


# Task 4: Data Cleaning (Handling Missing Values)
print("\n--- Task 4: Data Cleaning (Handling Missing Values) ---")
# Use 'df_sales' from Task 2 (which should have NaNs).
# 4.1 Check how many missing values are in each column. Store the result in 'missing_counts4_1'.
# 4.2 Fill missing 'Sales' values with the mean of the 'Sales' column. Store the modified DataFrame in 'df4_2_filled'.
# 4.3 Drop rows that have any missing values in 'df_sales'. Store the result in 'df4_3_dropped'.

# Your code for Task 4 here:


# 4.1 Check missing values in each column
missing_counts4_1 = df_sales.isnull().sum()

# 4.2 Fill missing Sales with mean Sales
df4_2_filled = df_sales.copy()

sales_mean = df4_2_filled['Sales'].mean()

df4_2_filled['Sales'] = df4_2_filled['Sales'].fillna(sales_mean)

# 4.3 Drop rows having any missing values
df4_3_dropped = df_sales.dropna()

print("Missing values:")
print(missing_counts4_1)

print("\nDataFrame after filling Sales:")
print(df4_2_filled)

print("\nDataFrame after dropping rows with missing values:")
print(df4_3_dropped)


# Task 5: Data Manipulation (Columns, Sorting, Grouping)
print("\n--- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---")
# Use 'df_sales' (the original one with NaNs)
# 5.1 Create a new column 'Total_Revenue' which is 'Sales' * 'Quantity'.
#     (Be mindful of NaNs, the result should also be NaN where either Sales or Quantity is NaN).
# 5.2 Sort 'df_sales' by 'Date' in ascending order, then by 'Sales' in descending order. Store it in 'df5_2_sorted'.
# 5.3 Group 'df_sales' by 'Region' and calculate the sum of 'Sales' and 'Quantity' for each region.
#     Store the result in 'df5_3_grouped_region'.
# 5.4 Group 'df_sales' by 'Product' and find the average 'Sales' for each product.
#     Store the result in 'df5_4_grouped_product'.

# Your code for Task 5 here:


# 5.1 Create Total_Revenue column
df_sales['Total_Revenue'] = df_sales['Sales'] * df_sales['Quantity']

# 5.2 Sort by Date ascending and Sales descending
df5_2_sorted = df_sales.sort_values(
    by=['Date', 'Sales'],
    ascending=[True, False]
)

# 5.3 Group by Region and calculate sum of Sales and Quantity
df5_3_grouped_region = df_sales.groupby('Region')[['Sales', 'Quantity']].sum()

# 5.4 Group by Product and calculate average Sales
df5_4_grouped_product = df_sales.groupby('Product')['Sales'].mean()

print("DataFrame with Total Revenue:")
print(df_sales)

print("\nSorted DataFrame:")
print(df5_2_sorted)

print("\nSales and Quantity by Region:")
print(df5_3_grouped_region)

print("\nAverage Sales by Product:")
print(df5_4_grouped_product)
# Out:
# --- Intermediate Pandas Exercise ---
# Complete each task by writing the requested Pandas code.
# ------------------------------------
#
# --- Task 1: Basic Pandas Functions and Converting Arrays to DataFrames ---
# Series:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# 90 2023-03-31 02:10:54.545454546  North  Laptop  874.0       4.0
# 92 2023-04-02 01:41:49.090909092  South  Laptop  224.0      10.0
# 93 2023-04-03 01:27:16.363636364  South  Laptop  642.0       6.0
# 94 2023-04-04 01:12:43.636363637  South  Laptop  106.0       6.0
# 95 2023-04-05 00:58:10.909090910  North  Laptop  892.0      10.0
# 97 2023-04-07 00:29:05.454545455   West  Laptop  541.0       4.0
# 98 2023-04-08 00:14:32.727272728  South  Laptop    NaN       2.0
# 99 2023-04-09 00:00:00.000000000   East  Laptop  907.0       8.0
#
# East region with Sales > 500:
#                             Date Region   Product  Sales  Quantity
# 5  2023-01-05 22:47:16.363636363   East   Monitor  518.0       2.0
# 8  2023-01-08 22:03:38.181818181   East    Laptop  536.0      10.0
# 10 2023-01-10 21:34:32.727272727   East     Mouse  959.0       6.0
# 21 2023-01-21 18:54:32.727272727   East  Keyboard  920.0       5.0
# 25 2023-01-25 17:56:21.818181818   East    Laptop  668.0       3.0
# 27 2023-01-27 17:27:16.363636364   East     Mouse  773.0       9.0
# 41 2023-02-10 14:03:38.181818182   East  Keyboard  518.0       3.0
# 47 2023-02-16 12:36:21.818181818   East  Keyboard  754.0       8.0
# 67 2023-03-08 07:45:27.272727273   East    Laptop  936.0       6.0
# 68 2023-03-09 07:30:54.545454546   East   Monitor  803.0       2.0
# 74 2023-03-15 06:03:38.181818182   East  Keyboard  986.0       9.0
# 85 2023-03-26 03:23:38.181818182   East     Mouse  975.0       NaN
# 86 2023-03-27 03:09:05.454545455   East  Keyboard  692.0       2.0
# 99 2023-04-09 00:00:00.000000000   East    Laptop  907.0       8.0
#
# First Monitor Sales: nan
#
# --- Task 4: Data Cleaning (Handling Missing Values) ---
# Missing values:
# Date        0
# Region      0
# Product     0
# Sales       5
# Quantity    3
# dtype: int64
#
# DataFrame after filling Sales:
#                             Date Region   Product       Sales  Quantity
# 0  2023-01-01 00:00:00.000000000  South     Mouse  171.000000      10.0
# 1  2023-01-01 23:45:27.272727272  South  Keyboard  751.000000       2.0
# 2  2023-01-02 23:30:54.545454545  North  Keyboard  550.000000       9.0
# 3  2023-01-03 23:16:21.818181818  South    Laptop  391.000000       7.0
# 4  2023-01-04 23:01:49.090909090   East   Monitor  541.294737       7.0
# ..                           ...    ...       ...         ...       ...
# 95 2023-04-05 00:58:10.909090910  North    Laptop  892.000000      10.0
# 96 2023-04-06 00:43:38.181818182   West  Keyboard  901.000000       9.0
# 97 2023-04-07 00:29:05.454545455   West    Laptop  541.000000       4.0
# 98 2023-04-08 00:14:32.727272728  South    Laptop  541.294737       2.0
# 99 2023-04-09 00:00:00.000000000   East    Laptop  907.000000       8.0
#
# [100 rows x 5 columns]
#
# DataFrame after dropping rows with missing values:
#                             Date Region   Product  Sales  Quantity
# 0  2023-01-01 00:00:00.000000000  South     Mouse  171.0      10.0
# 1  2023-01-01 23:45:27.272727272  South  Keyboard  751.0       2.0
# 2  2023-01-02 23:30:54.545454545  North  Keyboard  550.0       9.0
# 3  2023-01-03 23:16:21.818181818  South    Laptop  391.0       7.0
# 5  2023-01-05 22:47:16.363636363   East   Monitor  518.0       2.0
# ..                           ...    ...       ...    ...       ...
# 94 2023-04-04 01:12:43.636363637  South    Laptop  106.0       6.0
# 95 2023-04-05 00:58:10.909090910  North    Laptop  892.0      10.0
# 96 2023-04-06 00:43:38.181818182   West  Keyboard  901.0       9.0
# 97 2023-04-07 00:29:05.454545455   West    Laptop  541.0       4.0
# 99 2023-04-09 00:00:00.000000000   East    Laptop  907.0       8.0
#
# [92 rows x 5 columns]
#
# --- Task 5: Data Manipulation (Columns, Sorting, Grouping) ---
# DataFrame with Total Revenue:
#                             Date Region   Product  Sales  Quantity  \
# 0  2023-01-01 00:00:00.000000000  South     Mouse  171.0      10.0
# 1  2023-01-01 23:45:27.272727272  South  Keyboard  751.0       2.0
# 2  2023-01-02 23:30:54.545454545  North  Keyboard  550.0       9.0
# 3  2023-01-03 23:16:21.818181818  South    Laptop  391.0       7.0
# 4  2023-01-04 23:01:49.090909090   East   Monitor    NaN       7.0
# ..                           ...    ...       ...    ...       ...
# 95 2023-04-05 00:58:10.909090910  North    Laptop  892.0      10.0
# 96 2023-04-06 00:43:38.181818182   West  Keyboard  901.0       9.0
# 97 2023-04-07 00:29:05.454545455   West    Laptop  541.0       4.0
# 98 2023-04-08 00:14:32.727272728  South    Laptop    NaN       2.0
# 99 2023-04-09 00:00:00.000000000   East    Laptop  907.0       8.0
#
#     Total_Revenue
# 0          1710.0
# 1          1502.0
# 2          4950.0
# 3          2737.0
# 4             NaN
# ..            ...
# 95         8920.0
# 96         8109.0
# 97         2164.0
# 98            NaN
# 99         7256.0
#
# [100 rows x 6 columns]
#
# Sorted DataFrame:
#                             Date Region   Product  Sales  Quantity  \
# 0  2023-01-01 00:00:00.000000000  South     Mouse  171.0      10.0
# 1  2023-01-01 23:45:27.272727272  South  Keyboard  751.0       2.0
# 2  2023-01-02 23:30:54.545454545  North  Keyboard  550.0       9.0
# 3  2023-01-03 23:16:21.818181818  South    Laptop  391.0       7.0
# 4  2023-01-04 23:01:49.090909090   East   Monitor    NaN       7.0
# ..                           ...    ...       ...    ...       ...
# 95 2023-04-05 00:58:10.909090910  North    Laptop  892.0      10.0
# 96 2023-04-06 00:43:38.181818182   West  Keyboard  901.0       9.0
# 97 2023-04-07 00:29:05.454545455   West    Laptop  541.0       4.0
# 98 2023-04-08 00:14:32.727272728  South    Laptop    NaN       2.0
# 99 2023-04-09 00:00:00.000000000   East    Laptop  907.0       8.0
#
#     Total_Revenue
# 0          1710.0
# 1          1502.0
# 2          4950.0
# 3          2737.0
# 4             NaN
# ..            ...
# 95         8920.0
# 96         8109.0
# 97         2164.0
# 98            NaN
# 99         7256.0
#
# [100 rows x 6 columns]
#
# Sales and Quantity by Region:
#           Sales  Quantity
# Region
# East    13260.0     116.0
# North   12064.0     149.0
# South   16317.0     190.0
# West     9782.0     126.0
#
# Average Sales by Product:
# Product
# Keyboard    583.227273
# Laptop      554.965517
# Monitor     502.857143
# Mouse       519.043478
# Name: Sales, dtype: float64
